# %%
import import_ipynb
from . import people
from . import items
from . import interactions
from . import inventory

# %%
#INVENTORY
invenGun = {
    "descText": inventory.Gun.desc,
    "actions": {
        "Shoot yourself.": inventory.Gun.shootSelf
    }
}

invenConsumableGoods = {
    "descText": inventory.ConsumableGoods.desc,
    "actions": {
        "Eat them!": inventory.ConsumableGoods.eat
    }
}

invenArtisanalContract = {
    "descText": inventory.ArtisanalContract.desc,
    "actions": {
        "Open and read the contents": inventory.ArtisanalContract.read
    }
}

invenMistmossLeaflet = {
    "descText": inventory.MistmossLeaflet.desc,
    "actions": {
        "Read the flyer": inventory.MistmossLeaflet.read
    }
}

invenWhiteBook = {
    "descText": inventory.WhiteBook.desc,
    "actions": {
        "Open the white book": inventory.WhiteBook.read
    }
}

invenBlackBook = {
    "descText": inventory.BlackBook.desc,
    "actions": {
        "Open the black book": inventory.BlackBook.read
    }
}

invenAbout = {
    "descText": inventory.About.desc,
    "actions": {
        "Read the full poem": inventory.About.poem
    }
}

# %%
#PEOPLE
dancingBoy = {
    "enterText": "A pale boy twirls in the corner with a peaceful half-smile on his face.",
    "menuText": {
        "Watch the dancer": people.DancingBoy.firstMeeting
    }
}

dancingBoy2 = {
    "enterText": "The boy looks up at you, head tilted.",
    "menuText": {
        "Approach him": people.DancingBoy.talk
    }
}

dancingBoy3 = {
    "enterText": "A girl with a helmet on looks up as you enter. She and the boy are seated across from one another, playing chess (since when did he have a chessboard?)",
    "menuText": {
        "Watch the game": people.DancingBoy.watchChess
    }
}

dancingBoy4 = {
    "enterText": "He looks at you with fingers tapping nervously.",
    "menuText": {
        "Wait": people.DancingBoy.wait
    }
}

dancingBoy5 = {
    "enterText": "The boy watches you warily.",
    "menuText": {
        "Wait": people.DancingBoy.talk
    }
}

Bob = {
    "enterText": "Bob's in the corner!",
    "menuText": {
        "Talk to Bob": people.Bob.talk
    }
}

Bob2 = {
    "enterText": "Bob2 corner!",
    "menuText": {
        "Talk to Bob2222222": people.Bob2.talk
    }
}

# %%
#ITEMS
gun = {
    "enterText": "There's a gun on the floor.",
    "menuText": {
        "Pick up gun?!": items.Gun.pick
    }
}

consumableGoods = {
    "enterText": "A uniquely bland...thing lies on the floor, avoiding your gaze. Somehow you can't focus on it, but you know it's there. Something this generic deserves a generic name...",
    "menuText": {
        "Pick up the consumables": items.ConsumableGoods.pick
    }
}

artisanalContract = {
    "enterText": "What appears to be a letter hides itself beneath a sizable rock.",
    "menuText": {
        "Move the rock and take the letter": items.ArtisanalContract.pick
    }
}

enlightenedBook = {
    "enterText": "A solid black book now lies on the table, waiting to be collected.",
    "menuText": {
        "Pick up the black book": items.Book.enlightenedPick
    }
}

unenlightenedBook = {
    "enterText": "A thrum runs through you, not quite pleasant, and an undecorated white book lying on a table makes its presence known.",
    "menuText": {
        "Pick up the white book": items.Book.unenlightenedPick
    }
}

mistmossLeaflet = {
    "enterText": "A piece of paper nearby avoids being blown away by hanging onto a rock.",
    "menuText": {
        "Pick up the paper": items.MistmossLeaflet.pick
    }
}

# %%
#INTERACTIONS
moveWest = {
    "enterText": "You can go west: cave",
    "menuText": {
        "Go west!": interactions.MovedWest.move
    }
}

shootTarget = {
    "enterText": "There's a fragile target here.",
    "menuText": {
        "BAM BAM!": interactions.shootTarget.shoot
    }
}

moveEast = {
    "enterText": "The east is still open.",
    "menuText": {
        "Head back east": interactions.MovedEast.move
    }
}

returnGoods = {
    "enterText": "TODO",
    "menuText": {
        "Return goods TODO": interactions.Goods.give
    }
}

mistMachineBox = {
    "enterText": "A metallic box, once bronzed, now rusted, lies enclaved within the wall. A low-pitched humming resonates bodily.",
    "menuText": {
        "Inspect the box": interactions.MistMachine.inspect
    }
}

mistmoss = {
    "enterText": "A pervading moss decorates the hillside, arranged serenely.",
    "menuText": {
        "Admire the moss": interactions.Mistmoss.inspect
    }
}

stoneGraveStones = {
    "enterText": "A pile of stones marks off a grave, but the earth it guards is disturbed.",
    "menuText": {
        "Kneel": interactions.StoneGraveStones.inspect
    }
}

skull = {
    "enterText": "A skull has somehow found its way into this shack. Although its teeth are grinning, it looks rather melancholic.",
    "menuText": {
        "Listen to the skull": interactions.Skull.listen
    }
}

inspectRuinsFactoryInner = {
    "enterText": "Looking around, this room seems to be an office space of some sort. Machinery which has somehow found its way in stops you from progressing too far in.",
    "menuText": {
        "Inspect the room": interactions.RuinsFactoryInner.inspect
    }
}

waitingRuinsFactoryInner = {
    "enterText": "This room is oddly peaceful...",
    "menuText": {
        "Think for a bit": interactions.RuinsFactoryInner.wait
    }
}

waiting = {
    "enterText": "The repetition of the houses fills your head with a muggy fog. Moving a bit slowly would be far more comfortable.",
    "menuText": {
        "Wait": interactions.Waiting.wait
    }
}

moveMeadows = {
    "enterText": "The entrance to the cave isn't far off.",
    "menuText": {
        "Leave": interactions.MoveMeadows.move
    }
}

moveMeadows2 = {
    "enterText": "The meadows can be seen just beyond.",
    "menuText": {
        "Return to the meadows": interactions.MoveMeadows.move2
    }
}

moveDancingCave = {
    "enterText": "There's a cave not far off, blending into the meadows seamlessly.",
    "menuText": {
        "Head towards the cave": interactions.MoveDancingCave.move
    }
}

moveMistMachine = {
    "enterText": "A small passageway opens up near the back, barely narrow enough to squeeze through.",
    "menuText": {
        "Go down the small passageway": interactions.MoveMistMachine.move
    }
}

moveStoneGrave = {
    "enterText": "A dirt trail leads away to a patch where the moss hasn't invaded.",
    "menuText": {
        "Follow the trail": interactions.MoveStoneGrave.move
    }
}

moveSummerHouse = {
    "enterText": "A path leads away to a glowing hill.",
    "menuText": {
        "Follow the path": interactions.MoveSummerHouse.move
    }
}

moveRuinsLibrary = {
    "enterText": "A cobbled road curves around the hills. At the end, the tip of a small home can be seen.",
    "menuText": {
        "Go down the road": interactions.MoveRuinsLibrary.move
    }
}

moveRuinsLibrary2 = {
    "enterText": "The tip of a small home can barely be made out over a nearby hill.",
    "menuText": {
        "Investigate the home": interactions.MoveRuinsLibrary.move2
    }
}

moveRuinsFactory = {
    "enterText": "A modest building can be seen, wood deepened from moisture and decomposing.",
    "menuText": {
        "Go towards the failing building": interactions.MoveRuinsFactory.move
    }
}

moveOutsideRuinsFactory = {
    "enterText": "The sunlight from outside seems almost blackened as it unkindly enters the building.",
    "menuText": {
        "Exit": interactions.MoveRuinsFactory.move
    }
}

moveIntoFactory = {
    "enterText": "The door into the building has long since been removed, and the negative space left behind beckons you.",
    "menuText": {
        "Enter the collapsing building.": interactions.MoveIntoFactory.move
    }
}

moveFurther = {
    "enterText": "TODO",
    "menuText": {
        "TODO cant": interactions.MoveFurther.move
    }
}

moveGiantsTown = {
    "enterText": "A residential area grows up out of the road further down, puzzlingly vast and far.",
    "menuText": {
        "Move towards the residential area": interactions.MoveGiantsTown.move
    }
}

# %%
#ROOMS
meadows = {
    "name": "[Meadows]",
    "enterText": "Wildflowers burst from the ground, giving the terrain a cheerfully wistful backdrop. A silence pervades the area - no birds chirp, no wind blows, and footfalls are muted."
}

dancingCave = {
    "name": "[Dancing Cave]",
    "enterText": "The cave's air is a humid tickle on the nose, causing a twitch. There's enough light from the entrance to see that this area is more like a grotto, lacking the deep, carved-out nature of a cave system."
}

mistMachine = {
    "name": "[Dancing Heart]",
    "enterText": "The claustrophobic room forces the boy to squeeze against you."
}

summerHouse = {
    "name": "[Summer House]",
    "enterText": "A small hill rises from the ground, topped by a stone foundation. Something must have been here at one point, but it has since vanished."
}

stoneGrave = {
    "name": "[Stone Grave]",
    "enterText": "The bright moss doesn't grow here, giving it a sharp contrast that brings clarity of mind."
}

ruinsLibrary = {
    "name": "[Ruins Library]",
    "enterText": "The structure, on closer inspection, transforms into a larger wooden lean-to lacking any familiar warm qualities."
}

ruinsFactory = {
    "name": "[Ruins Factory Outer]",
    "enterText": "It looks like this building was once used as some kind of production facility, with nearly-unrecognizable pieces of wooden machinery strewn about."
}

ruinsFactoryInner = {
    "name": "[Ruins Factory Inner]",
    "enterText": "The air is choking, painfully sharp. The dust has been recently disturbed - the shapes suggest something was dragged around the building for a while."
}

giantsTown = {
    "name": "[Giants Town]",
    "enterText": "What sparse homes there are around you are all strangely vandalized - a bell ringing, a bell tipped over, even a bell dancing - all some variation on a bell."
}

end = {
    "name": "[The End!]",
    "enterText": ""
}

sampleRoom = {
    "name": "[Beach]",
    "enterText": "Wow, you are in a room"
}

sampleRoom2 = {
    "name": "[Cave]",
    "enterText": "The second sample room..."
}
